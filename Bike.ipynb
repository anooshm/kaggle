# %%
# %matplotlib inline
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.cross_validation import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.grid_search import GridSearchCV
from sklearn.preprocessing import Imputer
from sklearn.ensemble import GradientBoostingClassifier
from datetime import datetime, date, time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter('ignore', DeprecationWarning)

# %%
data = pd.read_csv('/home/anoosh/Documents/kaggle/bike/train.csv', parse_dates=[0], infer_datetime_format=True)
test = pd.read_csv('/home/anoosh/Documents/kaggle/bike/test.csv',  parse_dates=[0], infer_datetime_format=True)
data.head(5)
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81          0       3          13     16
# 1        80          0       8          32     40
# 2        80          0       5          27     32
# 3        75          0       3          10     13
# 4        75          0       0           1      1
#
# [5 rows x 12 columns]

# %%
data.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
temp = pd.DatetimeIndex(data['datetime'])
data['Date'] = temp.date
data['Time'] = temp.time

# %%
features = pd.concat([data.get(['windspeed', 'humidity', 'temp', 'atemp', 'holiday', 'workingday']),
                      pd.get_dummies(data.weather, prefix='weather'),
                      pd.get_dummies(data.season, prefix='season'),
                      pd.get_dummies(data.Time, prefix = 'time')],
                     axis=1)
print list(data.columns)
target = np.squeeze(np.array(data.get(['count'])))
target.shape
y = np.squeeze(np.array(data.get(['count'])))
y.shape
# Out:
# ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count', 'Date', 'Time']
# (10886,)

# %%
list(features.columns)
# Out:
# ['windspeed',
#  'humidity',
#  'temp',
#  'atemp',
#  'holiday',
#  'workingday',
#  'weather_1',
#  'weather_2',
#  'weather_3',
#  'weather_4',
#  'season_1',
#  'season_2',
#  'season_3',
#  'season_4',
#  'time_00:00:00',
#  'time_01:00:00',
#  'time_02:00:00',
#  'time_03:00:00',
#  'time_04:00:00',
#  'time_05:00:00',
#  'time_06:00:00',
#  'time_07:00:00',
#  'time_08:00:00',
#  'time_09:00:00',
#  'time_10:00:00',
#  'time_11:00:00',
#  'time_12:00:00',
#  'time_13:00:00',
#  'time_14:00:00',
#  'time_15:00:00',
#  'time_16:00:00',
#  'time_17:00:00',
#  'time_18:00:00',
#  'time_19:00:00',
#  'time_20:00:00',
#  'time_21:00:00',
#  'time_22:00:00',
#  'time_23:00:00']

# %%
from sklearn.svm import SVR
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor

clf = RandomForestRegressor(n_estimators=100)
clf.fit(features, target)
print clf.score(features, target)
pred = clf.predict(features)
print pred
print 'finished'
# Out:
# 0.975443649666
# [  28.34    37.38    31.92  ...,  163.185  138.47    85.14 ]
# finished

# %%
target
# Out:
# array([ 16,  40,  32, ..., 168, 129,  88])
